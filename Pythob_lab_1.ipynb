# %%
print("Hello World !!!")
# Out:
# Hello World !!!

# %% [markdown]
# Python Runtime Concepts: Practice exercises.

# %%
# Example 1: Assignment is not copying:
a = 10
b = a
a = 20
print(b)
# Out:
# 10

# %% [markdown]
# Example 1: Questions.
#
# 1. Mutable.
# 2. Python rebinds the name.
# 3. Yes

# %%
# Example 2: Stack Frame Behavior
def f(x):
  x = x+1
  print(x)

n = 5
f(n)
print(n)
# Out:
# 6
# 5

# %% [markdown]
# Questions example 2:
# 1. Inmutable.
# 2. Python mutates the object..
# 3. No.

# %%
# Example 3: Immutable object behavior.

x = 5
print(id(x))

x+=1
print(id(x))
# Out:
# 11654504
# 11654536

# %% [markdown]
# Questions example 3:
# 1. Immutable
# 2. Rebind the name
# 3. No.

# %%
# Example 4: Mutable object behavior.

lst = [1, 2]
print(id(lst))
lst.append(3)
print(id(lst))
# Out:
# 131976108302016
# 131976108302016

# %% [markdown]
# Questions example 4:
# 1. Mutable = lst
# 2. Python mutate the object.
# 3. No.

# %%
# Example 5: Argument Passing (Immutable)
def change(x):
  x = x + 10

a = 5
change(a)
print(a)
# Out:
# 5

# %% [markdown]
# Questions example 5:
# 1. Immutable.
# 2. Rebind the name.
# 3. No

# %%
# Example 6: Argument passing (Mutable)
def change(lst):
  lst.append(99)

data=[1,2]
change(data)
print(data)
# Out:
# [1, 2, 99]

# %% [markdown]
# Questions example 6:
# 1. Mutable
# 2. It mutates.
# 3. Yes

# %%
# Example 7: Rebinding vs Mutation
def reset_wrong(lst):
  lst=[]

def reset_right(lst):
  lst.clear()

data = [1,2,3]
reset_wrong(data)
print(data)

reset_right(data)
print(data)
# Out:
# [1, 2, 3]
# []

# %% [markdown]
# Questions example 7:
# 1. Mutable.
# 2. rebind the name
# 3. No.

# %%
# Example 8: Identity Check
def demo(x):
  print(id(x))
  x.append(5)
  print(id(x))
lst = [1,2]
print(id(lst))
demo(lst)
# Out:
# 131975563564032
# 131975563564032
# 131975563564032

# %% [markdown]
# Question Example 8:
# 1. Mutable.
# 2. Python mutate the object.
# 3. Yes

# %%
# Example 9: Equality vs Identity
a = [1,2]
b = [1,2]

print(a==b)
print(a is b)
# Out:
# True
# False

# %% [markdown]
# Questions Example 9:
# 1. Mutable
# 2. Rebind the name
# 3. No.

# %%
# Example 10: Rebinding a name
x = [1,2]
x = [3,4]

# %% [markdown]
# Questions Example 10:
# 1. Mutable
# 2. Rebind the name
# 3. No.
